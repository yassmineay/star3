# %%
#!pip install tensorflow
#!pip install pixellib

# %%
#import the librery 
import pixellib
from pixellib.tune_bg import alter_bg
import matplotlib.pyplot as plt
from matplotlib import image

# %%
#change_bg is class object 
change_bg = alter_bg()

#load the model
change_bg.load_pascalvoc_model("deeplabv3_xception_tf_dim_ordering_tf_kernels.h5")

# %%
#show the sample
from matplotlib import image
sample = image.imread("sample.jpg")
plt.imshow(sample)

# %%
#show the backgound
backgroud1 = image.imread("background1.jpg")
plt.imshow(backgroud1)

# %%
output1=change_bg.change_bg_img(f_image_path = "sample.jpg",b_image_path = "background1.jpg", output_image_name="new_img1.jpg")

# %%
#show the new image
new_img1 = image.imread("new_img1.jpg")
plt.imshow(new_img1)

# %%
backgroud2 = image.imread("backgound2.jpg")
plt.imshow(backgroud2)

# %%
output2=change_bg.change_bg_img(f_image_path = "sample.jpg",b_image_path = "backgound2.jpg", output_image_name="new_img2.jpg")

# %%
new_img2 = image.imread("new_img2.jpg")
plt.imshow(new_img2)

# %%
backgroud3 = image.imread("backgound3.jpg")
plt.imshow(backgroud3)

# %%
output3=change_bg.change_bg_img(f_image_path = "sample.jpg",b_image_path = "backgound3.jpg", output_image_name="new_img3.jpg")

# %%
new_img3=image.imread("new_img3.jpg")
plt.imshow(new_img3)
